# %% [markdown]
# # Practica 2 - Visualizacion de datos

# %% [markdown]
# **Equipo:** 5

# %% [markdown]
# **Grupo:** 002 (Miércoles 6:00pm-9:00pm)

# %% [markdown]
# #### Integrantes:
#
# - 1688132 Martínez Loera Mario Vladimir
#
# - 1741667 Quiroz García Víctor Antonio
#
# - 1801994 Rodríguez Charles Karla Alejandra

# %% [markdown]
# # Base de datos principal

# %% [markdown]
# ## 1) Título de la base de datos
# - a) Heart Disease UCI
# - b) [enlace de base de datos](https://www.kaggle.com/ronitf/heart-disease-uci)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("heart.csv")

# %% [markdown]
# ### Estadística básica de los datos

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df['age'].describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
df.sum()
# Out:
# age         16473.0
# sex           207.0
# cp            293.0
# trestbps    39882.0
# chol        74618.0
# fbs            45.0
# restecg       160.0
# thalach     45343.0
# exang          99.0
# oldpeak       315.0
# slope         424.0
# ca            221.0
# thal          701.0
# target        165.0
# dtype: float64

# %%
df['age'].cumsum()
# Out:
# 0         63
# 1        100
# 2        141
# 3        197
# 4        254
#        ...
# 298    16246
# 299    16291
# 300    16359
# 301    16416
# 302    16473
# Name: age, Length: 303, dtype: int64

# %%
df['age'].count
# Out:
# <bound method Series.count of 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64>

# %%
df['age'].var()
# Out:
# 82.48455838961381

# %%
df['chol'].
# Out:
# <bound method Series.cumsum of 0      233
# 1      250
# 2      204
# 3      236
# 4      354
#       ...
# 298    241
# 299    264
# 300    193
# 301    131
# 302    236
# Name: chol, Length: 303, dtype: int64>

# %%
df['chol'].min()
# Out:
# 126

# %%
df['chol'].max()
# Out:
# 564

# %%
df['chol'].median()
# Out:
# 240.0

# %%
df['chol'].var()
# Out:
# 2686.4267479728114

# %%
df['chol'].std()
# Out:
# 51.830750987930045

# %%
df['chol'].skew()
# Out:
# 1.1434008206693387

# %%
df['chol'].kurt()
# Out:
# 4.505423167753712

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
df.cov()
# Out:
#                  age       sex        cp    trestbps         chol       fbs  \
# age        82.484558 -0.416661 -0.643499   44.495902   100.585076  0.392433
# sex        -0.416661  0.217166 -0.023736   -0.463970    -4.780309  0.007475
# cp         -0.643499 -0.023736  1.065132    0.861714    -4.113774  0.034719
# trestbps   44.495902 -0.463970  0.861714  307.586453   111.967215  1.109042
# chol      100.585076 -4.780309 -4.113774  111.967215  2686.426748  0.245427
# fbs         0.392433  0.007475  0.034719    1.109042     0.245427  0.126877
# restecg    -0.555013 -0.014261  0.024108   -1.052324    -4.116703 -0.015769
# thalach   -82.903318 -0.469871  6.991618  -18.759131   -11.800494 -0.069897
# exang       0.413022  0.031014 -0.191168    0.557111     1.631991  0.004295
# oldpeak     2.214583  0.051993 -0.178821    3.934486     3.246794  0.002377
# slope      -0.944791 -0.008819  0.076137   -1.312832    -0.128964 -0.013147
# ...

# %%
import pandas as pd
import matplotlib as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Graficar datos univariantes

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['age'].value_counts().head(10).plot.bar()
# Out:
# <AxesSubplot:>

# %%
(df['age'].value_counts().head(10) / len(df)).plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['trestbps'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['age'].value_counts().sort_index().plot.line()
# Out:
# <AxesSubplot:>

# %%
df['trestbps'].value_counts().sort_index().plot.line()
# Out:
# <AxesSubplot:>

# %%
df['age'].value_counts().sort_index().plot.area()
# Out:
# <AxesSubplot:>

# %%
df['trestbps'].value_counts().sort_index().plot.area()
# Out:
# <AxesSubplot:>

# %%
df[df['trestbps'] < 120]['trestbps'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[df['thalach'] < 120]['thalach'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['thalach'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ## Graficar datos bi-variantes

# %%
df[df['age'] < 77].plot.scatter(x='age', y='chol')
# Out:
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %%
df[df['age'] < 77].plot.hexbin(x='age', y='chol', gridsize=15)
# Out:
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %%
df[df['age'] < 77].plot.hexbin(x='age', y='chol', gridsize=5)
# Out:
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %%
df[df['age'] < 77].plot.scatter(x='age', y='trestbps')
# Out:
# <AxesSubplot:xlabel='age', ylabel='trestbps'>

# %%
df[df['age'] < 77].plot.hexbin(x='age', y='trestbps', gridsize=5)
# Out:
# <AxesSubplot:xlabel='age', ylabel='trestbps'>

# %% [markdown]
# ## Stacked plots

# %%
df.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df.plot.area()
# Out:
# <AxesSubplot:>

# %%
df.plot.line()
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns

# %%
sns.countplot(df['age'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
sns.kdeplot(df.query('thalach < 150').thalach)
# Out:
# <AxesSubplot:xlabel='thalach', ylabel='Density'>

# %%
df[df['thalach'] < 200]['thalach'].value_counts().sort_index().plot.line()
# Out:
# <AxesSubplot:>

# %%
sns.distplot(df['thalach'], bins=10, kde=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='thalach'>

# %%
sns.jointplot(x='age', y='thalach', data=df[df['age'] < 100])

# %%
sns.jointplot(x='age', y='thalach', data=df[df['age'] < 100], kind='hex',           
              gridsize=20)

# %% [markdown]
# ## Box plots

# %%
sns.boxplot(
    x='age',
    y='chol',
    data=df[df.age.isin(df.age.value_counts().head(5).index)]

)
# Out:
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %%
sns.violinplot(
    x='age',
    y='chol',
    data=df[df.age.isin(df.age.value_counts()[:5].index)]
)
# Out:
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %%
import pandas as pd
import pandas_profiling
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-133-1976b80f787d> in <module>
#       1 import pandas as pd
# ----> 2 import pandas_profiling
#
# ModuleNotFoundError: No module named 'pandas_profiling'

# %%
sns.pairplot(df[['age', 'chol', 'trestbps', 'thalach']])

# %% [markdown]
# ## Graficas multi variantes

# %%
import matplotlib.pyplot as plt

sns.lmplot(x='trestbps', y='chol', hue='sex', 
           data=df.loc[df['sex'].isin([0, 1])], 
           fit_reg=False)

# %%
fem = plt.hist(df[df["sex"] == 0].trestbps,bins=30,fc = (1,0,0,0.5),label = "Mujer")
men= plt.hist(df[df["sex"] == 1].trestbps,bins=30,fc = (0,1,0,0.5),label = "Hombre")
plt.legend()
plt.xlabel("Valor de la media del radio")
plt.ylabel("Frecuencia")
plt.title("Histograma")
plt.show()

# %%
mdata = pd.melt(df,id_vars = "sex",value_vars = ['trestbps', 'chol'])
plt.figure(figsize = (15,10))
sns.boxplot(x = "variable", y = "value", hue="sex",data= mdata)
plt.show()

# %%
f,ax=plt.subplots(figsize = (18,18))
sns.heatmap(df.corr(),annot= True,linewidths=0.5,fmt = ".1f",ax=ax)
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.title('Mapa de correlación')
plt.savefig('graph.png')
plt.show()

# %% [markdown]
# ### puntos extras

# %%
import matplotlib.pyplot as plt

# %%
genero=["Hombres", "Mujeres"]
df['sex'].value_counts().plot.pie(labels=genero, autopct="%0.1f %%")
# Out:
# <AxesSubplot:ylabel='sex'>

# %%
df['age'].value_counts().plot.pie(autopct="%0.1f %%")
# Out:
# <AxesSubplot:ylabel='age'>

# %%
dolor =["typical angina", "atypical angina", "non-anginal pain", "asymptomatic"]
df['cp'].value_counts().plot.pie(labels=dolor, autopct="%0.1f %%")
# Out:
# <AxesSubplot:ylabel='cp'>

# %% [markdown]
# # Base de datos secundaria

# %% [markdown]
# ## 1) Título de la base de datos
# - a) Spotify Dataset 1921-2020, 160k+ Tracks
# - b) [enlace de base de datos](https://www.kaggle.com/yamaerenay/spotify-dataset-19212020-160k-tracks)

# %%
df1 = pd.read_csv("data.csv")

# %%
df1.head()
# Out:
#    acousticness                    artists  danceability  duration_ms  energy  \
# 0      0.991000            ['Mamie Smith']         0.598       168333   0.224
# 1      0.643000  ["Screamin' Jay Hawkins"]         0.852       150200   0.517
# 2      0.993000            ['Mamie Smith']         0.647       163827   0.186
# 3      0.000173        ['Oscar Velazquez']         0.730       422087   0.798
# 4      0.295000                   ['Mixe']         0.704       165224   0.707
#
#    explicit                      id  instrumentalness  key  liveness  \
# 0         0  0cS0A1fUEUd1EW3FcF8AEI          0.000522    5    0.3790
# 1         0  0hbkKFIJm7Z05H8Zl9w30f          0.026400    5    0.0809
# 2         0  11m7laMUgmOKqI3oYzuhne          0.000018    0    0.5190
# 3         0  19Lc5SfJJ5O1oaxY0fpwfh          0.801000    2    0.1280
# 4         1  2hJjbsLCytGsnAHfdsLejp          0.000246   10    0.4020
#
#    loudness  mode                                               name  \
# ...

# %%
df1['duration_ms'].describe()
# Out:
# count    1.743890e+05
# mean     2.328100e+05
# std      1.483958e+05
# min      4.937000e+03
# 25%      1.661330e+05
# 50%      2.057870e+05
# 75%      2.657200e+05
# max      5.338302e+06
# Name: duration_ms, dtype: float64

# %%
df1.describe()
# Out:
#         acousticness   danceability   duration_ms         energy  \
# count  174389.000000  174389.000000  1.743890e+05  174389.000000
# mean        0.499228       0.536758  2.328100e+05       0.482721
# std         0.379936       0.176025  1.483958e+05       0.272685
# min         0.000000       0.000000  4.937000e+03       0.000000
# 25%         0.087700       0.414000  1.661330e+05       0.249000
# 50%         0.517000       0.548000  2.057870e+05       0.465000
# 75%         0.895000       0.669000  2.657200e+05       0.711000
# max         0.996000       0.988000  5.338302e+06       1.000000
#
#             explicit  instrumentalness            key       liveness  \
# count  174389.000000     174389.000000  174389.000000  174389.000000
# mean        0.068135          0.197252       5.205305       0.211123
# std         0.251978          0.334574       3.518292       0.180493
# min         0.000000          0.000000       0.000000       0.000000
# ...

# %% [markdown]
# Realizamos la descripción estadística para una columna porque cuando se realizaba para toda la base de datos se tardaba demasiado y a veces no daba nada

# %%
df1['acousticness'].mean()
# Out:
# 0.49922848176599677

# %%
df1['acousticness'].sum()
# Out:
# 87059.95570669

# %%
df1['acousticness'].skew()
# Out:
# -0.034517756135021845

# %%
df1.min()
# Out:
# acousticness                                                        0
# artists             ["'In The Heights' Original Broadway Company",...
# danceability                                                        0
# duration_ms                                                      4937
# energy                                                              0
# explicit                                                            0
# id                                             000G1xMMuwxNHmwVsBdtj1
# instrumentalness                                                    0
# key                                                                 0
# liveness                                                            0
# loudness                                                          -60
# mode                                                                0
# name                                                             "40"
# ...

# %%
df1.median()
# Out:
# acousticness             0.517000
# danceability             0.548000
# duration_ms         205787.000000
# energy                   0.465000
# explicit                 0.000000
# instrumentalness         0.000524
# key                      5.000000
# liveness                 0.138000
# loudness               -10.836000
# mode                     1.000000
# popularity              25.000000
# speechiness              0.045500
# tempo                  115.816000
# valence                  0.536000
# year                  1977.000000
# dtype: float64

# %%
df1.var()
# Out:
# acousticness        1.443512e-01
# danceability        3.098489e-02
# duration_ms         2.202131e+10
# energy              7.435737e-02
# explicit            6.349301e-02
# instrumentalness    1.119396e-01
# key                 1.237838e+01
# liveness            3.257762e-02
# loudness            3.239421e+01
# mode                2.090420e-01
# popularity          4.784167e+02
# speechiness         3.321877e-02
# tempo               9.153153e+02
# valence             6.994798e-02
# year                7.240378e+02
# dtype: float64

# %%
df1.corr()
# Out:
#                   acousticness  danceability  duration_ms    energy  explicit  \
# acousticness          1.000000     -0.263217    -0.089169 -0.750852 -0.208176
# danceability         -0.263217      1.000000    -0.100757  0.204838  0.200842
# duration_ms          -0.089169     -0.100757     1.000000  0.060516 -0.033808
# energy               -0.750852      0.204838     0.060516  1.000000  0.102561
# explicit             -0.208176      0.200842    -0.033808  0.102561  1.000000
# instrumentalness      0.221956     -0.215589     0.103621 -0.177750 -0.130609
# key                  -0.028028      0.026266     0.002020  0.035780  0.005282
# liveness             -0.029654     -0.110033     0.028942  0.134815  0.037288
# loudness             -0.546639      0.249541     0.019791  0.779267  0.106249
# mode                  0.064633     -0.048358    -0.046849 -0.056160 -0.062503
# popularity           -0.396744      0.123746     0.024717  0.328939  0.152545
# ...

# %%
df1.cov()
# Out:
#                   acousticness  danceability   duration_ms       energy  \
# acousticness          0.144351     -0.017604 -5.027410e+03    -0.077791
# danceability         -0.017604      0.030985 -2.631915e+03     0.009832
# duration_ms       -5027.410072  -2631.914662  2.202131e+10  2448.798306
# energy               -0.077791      0.009832  2.448798e+03     0.074357
# explicit             -0.019930      0.008908 -1.264173e+03     0.007047
# instrumentalness      0.028214     -0.012697  5.144733e+03    -0.016217
# key                  -0.037466      0.016267  1.054517e+03     0.034327
# liveness             -0.002034     -0.003496  7.751999e+02     0.006635
# loudness             -1.182075      0.250006  1.671538e+04     1.209433
# mode                  0.011227     -0.003892 -3.178651e+03    -0.007002
# popularity           -3.297037      0.476440  8.022832e+04     1.961914
# speechiness          -0.001554      0.007699 -2.646192e+03    -0.005597
# ...

# %% [markdown]
# ## Graficos univariantes

# %%
df1['artists'].value_counts().head(10).plot.bar()
# Out:
# <AxesSubplot:>

# %%
df1['duration_ms'].value_counts().head(10).sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df1['danceability'].value_counts().head(20).sort_index().plot.line()
# Out:
# <AxesSubplot:>

# %%
df1['duration_ms'].value_counts().head(80).sort_index().plot.line()
# Out:
# <AxesSubplot:>

# %%
df1['danceability'].value_counts().head(20).sort_index().plot.area()
# Out:
# <AxesSubplot:>

# %%
df1['duration_ms'].value_counts().head(20).sort_index().plot.area()
# Out:
# <AxesSubplot:>

# %%
df1[df1['danceability'] < 0.50]['danceability'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1[df1['tempo'] < 180]['tempo'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1['energy'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ## Graficar datos bi-variantes

# %%
df1[df1['danceability'] < 0.50].plot.scatter(x='danceability', y='duration_ms')
# Out:
# <AxesSubplot:xlabel='danceability', ylabel='duration_ms'>

# %%
df1[df1['danceability'] < 0.50].plot.hexbin(x='danceability', y='energy', gridsize=15)
# Out:
# <AxesSubplot:xlabel='danceability', ylabel='energy'>

# %%
df1[df1['danceability'] < 0.50].plot.hexbin(x='danceability', y='energy', gridsize=5)
# Out:
# <AxesSubplot:xlabel='danceability', ylabel='energy'>

# %%
df1[df1['danceability'] < 0.50].plot.hexbin(x='danceability', y='key', gridsize=15)
# Out:
# <AxesSubplot:xlabel='danceability', ylabel='key'>

# %%
df1[df1['danceability'] < 0.50].plot.hexbin(x='danceability', y='key', gridsize=5)
# Out:
# <AxesSubplot:xlabel='danceability', ylabel='key'>

# %% [markdown]
# ## Stacked plots

# %%
import seaborn as sns

# %%
sns.countplot(df1['danceability'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='danceability', ylabel='count'>

# %% [markdown]
# No pudimos realizar todas las Stacked plots debido principalmente a que los valores son muy distintos y también hay en algunas celdas datos diferentes por ejemplo fechas

# %%
sns.kdeplot(df1.query('loudness < 3.50').loudness)
# Out:
# <AxesSubplot:xlabel='loudness', ylabel='Density'>

# %%
df1[df1['danceability'] < 0.50]['danceability'].value_counts().sort_index().plot.line()
# Out:
# <AxesSubplot:>

# %%
sns.distplot(df1['valence'], bins=10, kde=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='valence'>

# %%
sns.jointplot(x='year', y='loudness', data=df1[df1['year'] > 2010])

# %%
sns.jointplot(x='year', y='danceability', data=df1[df1['year'] > 2010], kind='hex',           
              gridsize=20)

# %% [markdown]
# ## Box plots

# %%
sns.boxplot(
    x='key',
    y='energy',
    data=df1[df1.key.isin(df1.key.value_counts().head(5).index)]

)
# Out:
# <AxesSubplot:xlabel='key', ylabel='energy'>

# %%
sns.violinplot(
    x='year',
    y='danceability',
    data=df1[df1.year.isin(df1.year.value_counts()[:5].index)]
)
# Out:
# <AxesSubplot:xlabel='year', ylabel='danceability'>

# %%
import pandas as pd
import pandas_profiling
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-124-1976b80f787d> in <module>
#       1 import pandas as pd
# ----> 2 import pandas_profiling
#
# ModuleNotFoundError: No module named 'pandas_profiling'

# %%
sns.pairplot(df1[['key', 'danceability', 'energy', 'valence']])

# %% [markdown]
# ## Graficas multi variantes

# %%
sns.lmplot(x='key', y='danceability', hue='key', 
           data=df1.loc[df1['key'].isin([0, 2,5,5,6,8,9,10])], 
           fit_reg=False)

# %%
fem = plt.hist(df1[df1["mode"] == 0].year,bins=30,fc = (1,0,0,0.5),label = "0")
men= plt.hist(df1[df1["mode"] == 1].year,bins=30,fc = (0,1,0,0.5),label = "1")
plt.legend()
plt.xlabel("Valor de la media del radio")
plt.ylabel("Frecuencia")
plt.title("Histograma")
plt.show()

# %%
mdata = pd.melt(df1,id_vars = "key",value_vars = ['danceability', 'energy'])
plt.figure(figsize = (15,10))
sns.boxplot(x = "variable", y = "value", hue="key",data= mdata)
plt.show()

# %%
f,ax=plt.subplots(figsize = (18,18))
sns.heatmap(df1.corr(),annot= True,linewidths=0.5,fmt = ".1f",ax=ax)
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.title('Mapa de correlación')
plt.savefig('graph.png')
plt.show()

# %% [markdown]
# ##### Puntos extras (comparación de graficas)

# %% [markdown]
# Se revisará la comparación de la base de principal en las graficas de box plot

# %%
sns.boxplot(
    x='age',
    y='chol',
    data=df[df.age.isin(df.age.value_counts().head(5).index)]

)
# Out:
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %%
sns.violinplot(
    x='age',
    y='chol',
    data=df[df.age.isin(df.age.value_counts()[:5].index)]
)
# Out:
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %% [markdown]
# Aunque sea el mismo tipo de gráfica, pero de diferente forma, una es de violín y otra un box plot normal
# La grafica de violín para nosotros nos damas información dado a que podemos ver que entre mas amplio sea quiere decir que hay más pacientes con ese nivel de colesterol mientras tanto en la grafica de box plot normal solo es algo ya estándar
